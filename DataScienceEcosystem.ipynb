# %%
# Data Science Tools and Ecosystem

# %%
# In this notebook provides an overview of key tools and ecosystem used in Data Science. It highlights popular programming languages, libraries and development tools.

# %%
Some of the languages in vogue with Data Scientists are
1. R
2. Python
3. SQL

# %%
Some of the commom libraries used by Data Scientists are:
1. TensorFlow
2. Numpy
3. Pandas

# %%
| Data Science Tools |
|-------------------|
| Apache Zeppelin    |
| Jupyter Notebooks  |
| RStudios           |

# %%
### Here's a few examples of the arithmetic expressions evaluation in Python

# %%
# This is a simple arithmetic expression to multiply then add intergers
(10-2)/4
the expected output for this expression would be 2

# %%
# This will convert 200 minutes to hours by diving it by 60
200 / 60
# output = 3.333

# %%
**Objectives:**
- Enumerate popular languages for Data Science
- Perform simple arithmetic expressions in Python
- Overview of Data Science Tools and libraries

# %%
## Author
Fabio Euzebio de Paula
